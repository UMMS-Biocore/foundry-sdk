# %%
from viafoundry.client import ViaFoundryClient
client = ViaFoundryClient(".vialocal", enable_session_history=True)
# client.configure_auth(username=username, password=password, hostname=host)

# %%
# List all menu groups

menu_groups = client.process.list_menu_groups()
print("Available Menu Groups:")
for group in menu_groups["data"]:
    print(f"ID: {group['id']}, Name: {group['name']}")
# Out:
# Available Menu Groups:
# ID: 11, Name: Test Group
# ID: 12, Name: Misc

# %%
parameters = client.process.list_parameters()
parameters
# Out:
# [ServerParameterResponse(id=94, name='csv_test', qualifier='file', fileType='csv'),
#  ServerParameterResponse(id=93, name='test123', qualifier='file', fileType='csv'),
#  ServerParameterResponse(id=95, name='test1234', qualifier='file', fileType='csv')]

# %%
# List all parameters
all_params = client.process.list_parameters()
for param in all_params:
    print(f"  ID: {param.id}, Name: {param.name}, Qualifier: {param.qualifier}, FileType: {param.fileType}")
# Out:
#   ID: 94, Name: csv_test, Qualifier: file, FileType: csv
#   ID: 93, Name: test123, Qualifier: file, FileType: csv
#   ID: 95, Name: test1234, Qualifier: file, FileType: csv

# %%
#client.process.filter_parameters(qualifier='file')
#client.process.filter_parameters(name='fastq')
#client.process.filter_parameters(fileType='csv')
#client.process.filter_parameters(id_='134')
client.process.filter_parameters(qualifier='file', fileType='csv')
#client.process.filter_parameters(qualifier='val', fileType='label')
# Out:
# ID: 94, Name: csv_test, Qualifier: file, FileType: csv
# ID: 93, Name: test123, Qualifier: file, FileType: csv
# ID: 95, Name: test1234, Qualifier: file, FileType: csv
# [ServerParameterResponse(id=94, name='csv_test', qualifier='file', fileType='csv'),
#  ServerParameterResponse(id=93, name='test123', qualifier='file', fileType='csv'),
#  ServerParameterResponse(id=95, name='test1234', qualifier='file', fileType='csv')]

# %%
client.process.create_menu_group(name="Test Group")
# Out:
# {'id': 11, 'name': 'Test Group'}

# %%
script_body = """
   mkdir -p normalized_data
   normalize_qc.py --input ${cleaned_data} --output normalized_data --exclude_columns ${exclude_columns}
"""

# %%
process_config = client.process.create_process_config(
    name="new_test2",
    menu_group_name="Misc",
    input_params=[
        {

            "name": "csv_test",
            "displayName": "normalized_data",
            "fileType": "csv",
            "qualifier": "file",
            "optional": False,
            "test": "testfile.csv"
        }
    ],
    output_params=[
        {
            "name": "test1234",
            "displayName": "test_cleaned",
            "fileType": "csv",
            "qualifier": "file",
            "optional": False
        }
    ],
    summary="",
    script_body=f"script:\n\"\"\"\n{script_body}\n\"\"\"",
    script_language="Shell",
    permission_settings={
        "viewPermissions": 3,
        "writeGroupIds": []
    },
    revision_comment="Initial revision"
)
import json
process_config
print(json.dumps(process_config.model_dump(), indent=2))
# Out:
# ID: 94, Name: csv_test, Qualifier: file, FileType: csv
# ID: 95, Name: test1234, Qualifier: file, FileType: csv
# {
#   "name": "new_test2",
#   "summary": "",
#   "menuGroupId": 12,
#   "inputParameters": [
#     {
#       "parameterId": 94,
#       "displayName": "normalized_data",
#       "operator": "",
#       "operatorContent": "",
#       "optional": false,
#       "test": "testfile.csv"
#     }
#   ],
#   "outputParameters": [
#     {
#       "parameterId": 95,
#       "displayName": "test_cleaned",
#       "operator": "",
#       "operatorContent": "",
#       "optional": false,
#       "test": ""
#     }
#   ],
#   "revisionComment": "Initial revision",
#   "script": {
#     "body": "script:\n\"\"\"\n\n   mkdir -p normalized_data\n   normalize_qc.py --input ${cleaned_data} --output normalized_data --exclude_columns ${exclude_columns}\n\n\"\"\"",
#     "header": "",
#     "footer": "",
#     "language": "Shell"
#   },
#   "permissionSettings": {
#     "viewPermissions": 3,
#     "sharedGroupId": null,
#     "writeGroupIds": []
#   }
# }

# %%
client.process.create_process(process_data=process_config)
# Out:
# ProcessResponse(id=70, inputs=[ParameterResponse(parameter_id=94, sname='normalized_data', id=303, operator='', closure='', reg_ex='', optional='', name='csv_test', file_type='csv', qualifier='file')], outputs=[ParameterResponse(parameter_id=95, sname='test_cleaned', id=304, operator='', closure='', reg_ex='', optional='', name='test1234', file_type='csv', qualifier='file')], process_group_id=12, name='new_test2', summary='', script='script:\n"""\n\n   mkdir -p normalized_data\n   normalize_qc.py --input ${cleaned_data} --output normalized_data --exclude_columns ${exclude_columns}\n\n"""', script_mode='Shell', script_header='', script_footer='', script_mode_header='', run_pid=None, run_uuid=None, run_status=None, script_test_mode='', script_test='', singu_options=None, singu_img='', docker_opt='', docker_img='', singu_check=0, docker_check=0, test_work_dir='', test_env='', publish=None, publicly_searchable=None, owner_id=2, group_id=0, write_group_id='', perms=3, deleted=0, date_created='2025-06-18T14:25:28.000Z', date_modified='2025-06-18T14:25:28.000Z', last_modified_user=None, rev_id=0, rev_comment='Initial revision', process_gid=1, process_rev_uuid='8cb3a26ea3c2408da9d8f89b94cc4851', process_uuid='251d2326653a4ea88150aa9675e99a64')

# %%
# Update the summary of the previous process configuration
process_config.summary = "This process normalizes QC data and saves the output to the normalized_data directory a new change."

# Update the process on the server
client.process.update_process(process_id=69, process_data=process_config)
# Out:
# ProcessResponse(id=69, inputs=[ParameterResponse(parameter_id=94, sname='normalized_data', id=305, operator='', closure='', reg_ex='', optional='', name='csv_test', file_type='csv', qualifier='file')], outputs=[ParameterResponse(parameter_id=95, sname='test_cleaned', id=306, operator='', closure='', reg_ex='', optional='', name='test1234', file_type='csv', qualifier='file')], process_group_id=12, name='new_test2', summary='This process normalizes QC data and saves the output to the normalized_data directory a new change.', script='script:\n"""\n\n   mkdir -p normalized_data\n   normalize_qc.py --input ${cleaned_data} --output normalized_data --exclude_columns ${exclude_columns}\n\n"""', script_mode='Shell', script_header='', script_footer='', script_mode_header='', run_pid=None, run_uuid=None, run_status=None, script_test_mode='', script_test='', singu_options=None, singu_img='', docker_opt='', docker_img='', singu_check=0, docker_check=0, test_work_dir='', test_env='', publish=None, publicly_searchable=None, owner_id=2, group_id=None, write_group_id='', perms=3, deleted=0, date_created='2025-06-17T20:41:31.000Z', date_modified='2025-06-18T14:25:33.000Z', last_modified_user='2', rev_id=0, rev_comment='Initial revision', process_gid=0, process_rev_uuid='37ce0100a2aa41ce9a192996a61fae07', process_uuid='9fac842aa939425bb7898840c003fa35')

# %%
client.process.create_parameter({
    "name": "csv",
    "fileType": "csv",
    "qualifier": "file",
})
# Out:
# ServerParameterResponse(id=96, name='csv', qualifier='file', fileType='csv')

# %%
client.process.delete_parameter(parameter_id=96)
# Out:
# {'message': 'Parameter 96 successfully deleted'}
